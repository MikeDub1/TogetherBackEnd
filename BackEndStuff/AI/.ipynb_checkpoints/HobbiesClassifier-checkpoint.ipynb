# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.metrics import accuracy_score, hamming_loss, classification_report

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

from skmultilearn.problem_transform import BinaryRelevance, ClassifierChain, LabelPowerset
from skmultilearn.adapt import MLkNN

from sklearn.feature_extraction.text import CountVectorizer

from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
#Load Dataset

df = pd.concat([pd.read_csv('books.csv'), pd.read_csv('Cooking.csv'), pd.read_csv('cookingforbeginners.csv'), pd.read_csv('Games.csv'), pd.read_csv('GYM.csv'), pd.read_csv('videogames.csv'), pd.read_csv('travel.csv')])

# %%
df.to_csv('allHobbies.csv')

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#            id subreddit                                               body
# 0      lsz3fa     books  brief hiatus r book pleas recomm month book cl...
# 1     gou1a0c     books  date read schedul discuss thread discuss threa...
# 2     gouegbm     books  realli appreci mention thing spoiler tag there...
# 3     gp2fs0h     books  favorit book time read mani time got part memo...
# 4     gp0vwtb     books  releas end stint read book tri time get mayb t...
# ...       ...       ...                                                ...
# 5276   m3lfxc    travel                                                NaN
# 5277   m3l1g7    travel  weve watch nhk world get mini travel fix super...
# 5278  gqpd4mr    travel  channel anthoni bourdain part unknown regular ...
# 5279  gqpgeq9    travel  neighborhood japanes groceri store food court ...
# 5280  gqps4ml    travel      that neat thank gem yeah fun live oversea too
#
# [5281 rows x 3 columns]

# %%
vectorizer = CountVectorizer(stop_words='english')

# %%
df = df.dropna()

# %%
all_features = vectorizer.fit_transform(df.body)

# %%
all_features.shape
# Out:
# (5250, 10265)

# %%
vectorizer.vocabulary_
# Out:
# {'brief': 1039,
#  'hiatus': 4087,
#  'book': 946,
#  'pleas': 6671,
#  'recomm': 7233,
#  'month': 5693,
#  'club': 1612,
#  'march': 5333,
#  'read': 7179,
#  'rant': 7143,
#  'oral': 6204,
#  'histori': 4115,
#  'buster': 1162,
#  'casey': 1301,
#  'chuck': 1527,
#  'palahniuk': 6353,
#  'week': 9875,
#  'discuss': 2421,
#  'thread': 9028,
#  'join': 4701,
#  'ama': 243,
#  'tuesday': 9309,
#  'th': 8958,
#  'goodread': 3695,
#  'https': 4236,
#  'www': 10080,
#  'com': 1679,
#  'feel': 3143,
#  'free': 3399,
#  'skip': 8127,
#  'prefer': 6813,
#  'know': 4863,
#  'noth': 6010,
#  'effici': 2728,
#  'serial': 7893,
#  'killer': 4824,
#  'time': 9081,
#  'high': 4092,
#  'school': 7770,
#  'rebel': 7200,
#  'escap': 2887,
#  'small': 8193,
#  'town': 9190,
#  'home': 4156,
#  'big': 821,
#  'citi': 1554,
#  'becom': 742,
#  'leader': 4975,
#  'urban': 9550,
#  'demolit': 2250,
#  'derbi': 2277,
#  'parti': 6414,
#  'crash': 1963,
#  'die': 2346,
#  'spectacular': 8360,
#  'highway': 4099,
#  'death': 2178,
#  'friend': 3421,
#  'gather': 3543,
#  'testimoni': 8946,
#  'need': 5868,
#  'build': 1115,
#  'short': 8018,
#  'violent': 9715,
#  'life': 5052,
#  'content': 1821,
#  'warn': 9815,
#  'possibl': 6768,
#  'spoiler': 8410,
#  'rape': 7145,
#  'incest': 4396,
#  'pedophilia': 6485,
#  'gore': 3704,
#  'misogyni': 5604,
#  'homophobia': 4170,
#  'anim': 299,
#  'cruelti': 2024,
#  'date': 2148,
#  'link': 5086,
#  'sticki': 8547,
#  'comment': 1697,
#  'post': 6770,
#  'welcom': 9888,
#  'pace': 6334,
#  'dont': 2534,
#  'worri': 10032,
#  'later': 4950,
#  'usual': 9572,
#  'pretti': 6848,
#  'easi': 2686,
#  'catch': 1320,
#  'alway': 241,
#  'littl': 5105,
#  'like': 5067,
#  'view': 9698,
#  'past': 6436,
#  'select': 7855,
#  'want': 9805,
#  'thing': 9012,
#  'work': 10017,
#  'complet': 1729,
#  'archiv': 392,
#  'reddit': 7252,
#  'wiki': 9954,
#  'bookclub': 947,
#  'redesign': 7256,
#  'desktop': 2292,
#  'version': 9669,
#  'option': 6202,
#  'follow': 3317,
#  'receiv': 7215,
#  'notif': 6012,
#  'new': 5904,
#  'ad': 74,
#  'collect': 1667,
#  'test': 8943,
#  'perfect': 6520,
#  'perhap': 6525,
#  'make': 5288,
#  'easier': 2687,
#  'schedul': 7761,
#  'chapter': 1404,
#  'old': 6144,
#  'ly': 5234,
#  'end': 2805,
#  'awar': 570,
#  'contain': 1817,
#  'everyth': 2935,
#  'realli': 7192,
#  'appreci': 367,
#  'mention': 5468,
#  'tag': 8821,
#  'deal': 2172,
#  'breaker': 1025,
#  'im': 4346,
#  'glad': 3631,
#  'dodg': 2505,
#  'bullet': 1124,
#  'favorit': 3123,
#  'mani': 5311,
#  'got': 3710,
#  'memor': 5462,
#  'restart': 7407,
#  'day': 2156,
#  'finish': 3220,
#  'better': 802,
#  'everi': 2931,
#  'wait': 9784,
#  'releas': 7312,
#  'stint': 8553,
#  'tri': 9258,
#  'mayb': 5392,
#  'shot': 8024,
#  'great': 3831,
#  'choic': 1500,
#  'love': 5184,
#  'easili': 2689,
#  'involv': 4569,
#  'excit': 2961,
#  'start': 8506,
#  'haunt': 4001,
#  'mr': 5743,
#  'recent': 7216,
#  'bleak': 871,
#  'differ': 2351,
#  'felt': 3149,
#  'forev': 3343,
#  'kinda': 4829,
#  'wish': 9981,
#  'hadnt': 3936,
#  'alreadi': 231,
#  'ago': 151,
#  'mix': 5623,
#  'awesom': 575,
#  'author': 545,
#  'genr': 3577,
#  'honest': 4173,
#  'didnt': 2345,
#  'think': 9013,
#  'novel': 6017,
#  'incred': 4415,
#  'uniqu': 9476,
#  'strang': 8591,
#  'imposs': 4375,
#  'said': 7648,
#  'particular': 6418,
#  'hate': 3998,
#  'id': 4309,
#  'mean': 5411,
#  'utter': 9579,
#  'anywho': 338,
#  'wasnt': 9827,
#  'year': 10141,
#  'reread': 7378,
#  'recommend': 7234,
#  'multipl': 5770,
#  'subsequ': 8657,
#  'came': 1225,
#  'deeper': 2205,
#  'understand': 9432,
#  'stori': 8576,
#  'boy': 995,
#  'slowli': 8189,
#  'look': 5147,
#  'forward': 3365,
#  'obtain': 6084,
#  'copi': 1869,
#  'choke': 1501,
#  'morn': 5706,
#  'librari': 5043,
#  'fc': 3127,
#  'damn': 2120,
#  'gave': 3547,
#  'oh': 6127,
#  'gosh': 3709,
#  'dislik': 2439,
#  'basic': 687,
#  'palahnuik': 6354,
#  'written': 10064,
#  'took': 9155,
#  'loooong': 5153,
#  'hope': 4187,
#  'enjoy': 2830,
#  'fun': 3456,
#  'pick': 6583,
#  'audiobook': 528,
#  'libbi': 5041,
#  'far': 3094,
#  'narrat': 5830,
#  'provid': 6943,
#  'fashion': 3103,
#  'world': 10025,
#  'war': 9806,
#  'decad': 2187,
#  'bunch': 1133,
#  'burn': 1146,
#  'couldv': 1911,
#  'yall': 10129,
#  'creat': 1976,
#  'altern': 235,
#  'cool': 1860,
#  'guy': 3919,
#  'person': 6534,
#  'youtub': 10193,
#  'watchv': 9836,
#  'rb': 7167,
#  'sakb': 7654,
#  'tpu': 9194,
#  'genius': 3575,
#  'sketch': 8115,
#  'children': 1476,
#  'fight': 3197,
#  'girl': 3623,
#  'pictur': 6588,
#  'reason': 7197,
#  'ill': 4340,
#  'ive': 4632,
#  'sever': 7914,
#  'sign': 8062,
#  'hes': 4079,
#  'extrem': 3021,
#  'resolut': 7397,
#  'readi': 7182,
#  'stoke': 8562,
#  'say': 7735,
#  'worth': 10037,
#  'stick': 8545,
#  'iron': 4589,
#  'halfway': 3949,
#  'becam': 738,
#  'mind': 5562,
#  'numb': 6037,
#  'dull': 2631,
#  'directionless': 2386,
#  'pointless': 6709,
#  'verbos': 9657,
#  'gross': 3863,
#  'plot': 6681,
#  'tiresom': 9098,
#  'eventu': 2929,
#  'sinc': 8091,
#  'peopl': 6505,
#  'curious': 2068,
#  'wow': 10045,
#  'fragil': 3381,
#  'psych': 6957,
#  'surviv': 8746,
#  'assault': 465,
#  'inform': 4458,
#  'consent': 1794,
#  'coupl': 1921,
#  'right': 7479,
#  'miss': 5608,
#  'thrill': 9034,
#  'weve': 9899,
#  'abl': 15,
#  'bring': 1049,
#  'team': 8885,
#  'approach': 368,
#  'watch': 9832,
#  'space': 8335,
#  'serv': 7897,
#  'purpos': 7005,
#  'larg': 4940,
#  'rang': 7141,
#  'array': 420,
#  'check': 1433,
#  'graphic': 3820,
#  'anoth': 312,
#  'alongsid': 225,
#  'particip': 6416,
#  'messag': 5485,
#  'suggest': 8685,
#  'yes': 10149,
#  'absolut': 27,
#  'expos': 3006,
#  'uncomfort': 9409,
#  'posit': 6767,
#  'outcom': 6258,
#  'shock': 8006,
#  'valu': 9608,
#  'dimension': 2369,
#  'human': 4248,
#  'harshest': 3990,
#  'light': 5060,
#  'pahulnick': 6344,
#  'tough': 9181,
#  'ti': 9048,
#  'hose': 4200,
#  'theme': 8984,
#  'avoid': 567,
#  'rest': 7406,
#  'includ': 4401,
#  'true': 9288,
#  'hella': 4054,
#  'hype': 4279,
#  'thank': 8963,
#  'share': 7950,
#  'enthusiasm': 2842,
#  'best': 794,
#  'doubt': 2555,
#  'earli': 2677,
#  'forgiv': 3349,
#  'come': 1684,
#  'critic': 2005,
#  'write': 10061,
#  'style': 8640,
#  'expir': 2997,
#  'catalog': 1317,
#  'combin': 1682,
#  'good': 3693,
#  'stop': 8571,
#  'charact': 1406,
#  'list': 5095,
#  'snuff': 8240,
#  'lullabi': 5215,
#  'invis': 4567,
#  'monster': 5688,
#  'imho': 4353,
#  'diari': 2335,
#  'fugit': 3450,
#  'refuge': 7281,
#  'befor': 755,
#  'difficult': 2354,
#  'definit': 2219,
#  'twice': 9337,
#  'hear': 4028,
#  'heard': 4029,
#  'way': 9845,
#  'rule': 7598,
#  'someth': 8283,
#  'similar': 8075,
#  'help': 4062,
#  'tast': 8859,
#  'current': 2071,
#  'wind': 9965,
#  'bird': 840,
#  'chronicl': 1524,
#  'subreddit': 8653,
#  'chanc': 1394,
#  'inclus': 4402,
#  'kind': 4828,
#  'rotat': 7556,
#  'intens': 4520,
#  'revis': 7442,
#  'concurr': 1760,
#  'alt': 233,
#  'explor': 3003,
#  'especi': 2892,
#  'chill': 1480,
#  'dude': 2628,
#  'listen': 5096,
#  'appear': 358,
#  'joe': 4698,
#  'rogan': 7525,
#  'podcast': 6700,
#  'learn': 4984,
#  'lot': 5173,
#  'holi': 4148,
#  'bicep': 818,
#  'batman': 702,
#  'hyperlink': 4282,
#  'point': 6707,
#  'fix': 3236,
#  'solid': 8271,
#  'satisfi': 7711,
#  'uncommon': 9410,
#  'rough': 7564,
#  'tie': 9060,
#  'ahead': 156,
#  'remix': 7339,
#  'exact': 2949,
#  'super': 8711,
#  'comparison': 1713,
#  'favourit': 3125,
#  'tooooooo': 9157,
#  'bad': 617,
#  'second': 7834,
#  'argument': 402,
#  'plan': 6644,
#  'sound': 8318,
#  'survivor': 8747,
#  'fav': 3120,
#  'bare': 671,
#  'rememb': 7335,
#  'happen': 3971,
#  'lol': 5137,
#  'trick': 9263,
#  'bing': 832,
#  'disturb': 2465,
#  'topic': 9162,
#  'touch': 9178,
#  'repetit': 7361,
#  'general': 3569,
#  'downhil': 2563,
#  'agre': 152,
#  'sentiment': 7877,
#  'pygmi': 7018,
#  'survior': 8745,
#  'whatev': 9907,
#  'woman': 10000,
#  'island': 4603,
#  'late': 4948,
#  'teen': 8905,
#  'recal': 7210,
#  'em': 2767,
#  'yeah': 10139,
#  'expect': 2986,
#  'odd': 6103,
#  'turn': 9324,
#  'unreli': 9512,
#  'stuff': 8634,
#  'unless': 9483,
#  'someon': 8282,
#  'strong': 8621,
#  'els': 2763,
#  'wrote': 10066,
#  'decid': 2191,
#  'probabl': 6884,
#  'cp': 1941,
#  'altogeth': 237,
#  'bore': 964,
#  'silli': 8071,
#  'invent': 4563,
#  'actual': 72,
#  'align': 206,
#  'literatur': 5102,
#  'havent': 4002,
#  'murakami': 5779,
#  'intend': 4519,
#  'soon': 8297,
#  'christma': 1520,
#  'gift': 3614,
#  'polaris': 6719,
#  'consid': 1797,
#  'news': 5911,
#  'ok': 6136,
#  'talk': 8837,
#  'suck': 8676,
#  'heart': 4031,
#  'movi': 5732,
#  'base': 682,
#  'star': 8495,
#  'sam': 7677,
#  'rockwel': 7523,
#  'anjelica': 301,
#  'huston': 4268,
#  'kelli': 4792,
#  'macdonald': 5249,
#  'faith': 3057,
#  'sourc': 8322,
#  'nd': 5856,
#  'musta': 5791,
#  'hell': 4053,
#  'ride': 7474,
#  'familiar': 3076,
#  'use': 9566,
#  'fuck': 3445,
#  'awe': 573,
#  'bend': 784,
#  'nut': 6043,
#  'crazi': 1971,
#  'rollercoast': 7535,
#  'biographi': 835,
#  'add': 82,
#  'pass': 6426,
#  'closer': 1604,
#  'match': 5379,
#  'synops': 8802,
#  'titl': 9102,
#  'coin': 1653,
#  'toss': 9171,
#  'opinion': 6193,
#  'qualiti': 7042,
#  'direct': 2385,
#  'quit': 7081,
#  'bag': 622,
#  'inflat': 4454,
#  'ego': 2734,
#  'play': 6658,
#  'role': 7530,
#  'diminish': 2370,
#  'stand': 8488,
#  'infuri': 4461,
#  'doom': 2538,
#  'stellar': 8536,
#  'concept': 1752,
#  'mark': 5347,
#  'tear': 8887,
#  'gotten': 3716,
#  'tell': 8912,
#  'twist': 9339,
#  'satir': 7709,
#  'shade': 7929,
#  'grey': 3843,
#  'beauti': 737,
#  'worst': 10036,
#  'consist': 1800,
#  'forgett': 3348,
#  'adjust': 94,
#  'ugh': 9372,
#  'break': 1023,
#  'fourth': 3370,
#  'wall': 9795,
#  'despis': 2296,
#  'stephen': 8540,
#  'king': 4833,
#  'dark': 2134,
#  'tower': 9189,
#  'head': 4014,
#  'self': 7856,
#  'masturbatori': 5377,
#  'bullshit': 1126,
#  'thought': 9024,
#  'amaz': 250,
#  'film': 3208,
#  'kibosh': 4815,
#  'doesnt': 2508,
#  'matter': 5386,
#  'introduct': 4556,
#  'experi': 2992,
#  'mod': 5649,
#  'condens': 1761,
#  'mega': 5442,
#  'order': 6210,
#  'consolid': 1802,
#  'diversifi': 2472,
#  'page': 6343,
#  'remov': 7342,
#  'poster': 6771,
#  'instead': 4505,
#  'tradit': 9205,
#  'continu': 1827,
#  'let': 5029,
#  'jump': 4734,
#  'repli': 7364,
#  'request': 7374,
#  'unrel': 9511,
#  'delet': 2229,
#  'cleanli': 1579,
#  'success': 8673,
#  'descript': 2286,
#  'sought': 8313,
#  'protagonist': 6932,
#  'set': 7904,
#  'atmospher': 507,
#  'subject': 8644,
#  'tv': 9330,
#  'game': 3508,
#  'exampl': 2952,
#  'sure': 8732,
#  'explain': 2998,
#  'length': 5017,
#  'level': 5033,
#  'header': 4016,
#  'guarante': 3889,
#  'remain': 7329,
#  'activ': 68,
#  'burst': 1152,
#  'hungri': 4258,
#  'sort': 8309,
#  'manual': 5322,
#  'app': 353,
#  'ignor': 4326,
#  'slake': 8147,
#  'desir': 2290,
#  'tasti': 8863,
#  'propos': 6924,
#  'apt': 377,
#  'suggestmeabook': 8686,
#  'manag': 5304,
#  'non': 5974,
#  'tolkien': 9134,
#  'fantasi': 3091,
#  'daevabad': 2102,
#  'trilog': 9271,
#  'dune': 2646,
#  'gunsling': 3915,
#  'seri': 7892,
#  'radar': 7096,
#  'kingkil': 4835,
#  'blood': 891,
#  'bone': 936,
#  'child': 1473,
#  'daughter': 2150,
#  'narnia': 5829,
#  'theyr': 9004,
#  'shes': 7976,
#  'overal': 6285,
#  'arch': 388,
#  'question': 7059,
#  'middl': 5533,
#  'wolv': 9999,
#  'calla': 1217,
#  'callahan': 1218,
#  'salem': 7665,
#  'necessari': 5864,
#  'advis': 112,
#  'seen': 7846,
#  'emot': 2780,
#  'futur': 3481,
#  'audibl': 525,
#  'site': 8106,
#  'anyhoo': 332,
#  'track': 9200,
#  'cred': 1981,
#  'save': 7727,
#  'spend': 8372,
#  'appeal': 357,
#  'gamer': 3514,
#  'sw': 8758,
#  'fan': 3079,
#  'deep': 2204,
#  'tension': 8927,
#  'realist': 7189,
#  'sci': 7772,
#  'fi': 3184,
#  'anyon': 334,
#  'translat': 9221,
#  'tolstoy': 9138,
#  'resurrect': 7417,
#  'busi': 1155,
#  'teach': 8883,
#  'motiv': 5721,
#  'address': 86,
#  'existenti': 2978,
#  'terror': 8940,
#  'dedic': 2201,
#  'accept': 39,
#  'loss': 5170,
#  'conscious': 1792,
#  'gormenghast': 3708,
#  'mervyn': 5482,
#  'peak': 6480,
#  'fyi': 3491,
#  'unfinish': 9453,
#  'sight': 8060,
#  'rothfuss': 7558,
#  'ghost': 3603,
#  'editor': 2719,
#  'babel': 600,
#  'josiah': 4709,
#  'bancroft': 647,
#  'confid': 1773,
#  'dragonl': 2580,
#  'margaret': 5334,
#  'weiss': 9887,
#  'traci': 9199,
#  'hickman': 4088,
#  'scad': 7740,
#  'univers': 9480,
#  'place': 6640,
#  'witcher': 9985,
#  'fall': 3065,
#  'categori': 1324,
#  'mountain': 5727,
#  'sing': 8094,
#  'nguy': 5920,
#  'phan': 6555,
#  'qu': 7035,
#  'mai': 5274,
#  'queue': 7065,
#  'basma': 692,
#  'abdel': 11,
#  'aziz': 595,
#  'annihil': 307,
#  'anna': 304,
#  'janko': 4658,
#  'blue': 905,
#  'fox': 3371,
#  'sj': 8113,
#  'perfum': 6523,
#  'patrick': 6451,
#  'skind': 8123,
#  'secondhand': 7836,
#  'svetlana': 8755,
#  'alexievich': 201,
#  'pandora': 6369,
#  'congo': 1785,
#  'albert': 192,
#  'nchez': 5854,
#  'pi': 6578,
#  'ol': 6143,
#  'anyth': 335,
#  'beat': 735,
#  'martian': 5357,
#  'watchmen': 9835,
#  'pigeon': 6597,
#  'drive': 2602,
#  'bus': 1153,
#  'final': 3211,
#  'eas': 2685,
#  'age': 140,
#  'merci': 5474,
#  'watson': 9840,
#  'pig': 6596,
#  'toast': 9115,
#  'kate': 4774,
#  'dicamillo': 2337,
#  'illustr': 4345,
#  'son': 8289,
#  'charlott': 1418,
#  'web': 9862,
#  'ivi': 4633,
#  'bean': 730,
#  'funni': 3466,
#  'hilari': 4103,
#  'childhood': 1474,
#  'regular': 7295,
#  'click': 1587,
#  'clack': 1562,
#  'moo': 5696,
#  'cow': 1935,
#  'type': 9346,
#  'huge': 4244,
#  'father': 3113,
#  'wave': 9843,
#  'sonali': 8290,
#  'deraniyagala': 2276,
#  'struck': 8624,
#  'chord': 1507,
#  'return': 7428,
#  'donatella': 2530,
#  'di': 2327,
#  'pietrantonio': 6594,
#  'les': 5024,
#  'miser': 5598,
#  'hopeless': 4188,
#  'longer': 5143,
#  'sustain': 8753,
#  'disappoint': 2397,
#  'contemporari': 1819,
#  'romanc': 7541,
#  'kiss': 4839,
#  'quotient': 7084,
#  'warm': 9813,
#  'fuzzi': 3484,
#  'clair': 1564,
#  'north': 5996,
#  'live': 5109,
#  'harri': 3988,
#  'august': 533,
#  'reborn': 7206,
#  'previous': 6855,
#  'span': 8339,
#  'societi': 8251,
#  'christa': 1517,
#  'wolf': 9996,
#  'cassandra': 1309,
#  'aslam': 458,
#  'map': 5325,
#  'lost': 5172,
#  'lover': 5188,
#  'grandson': 3815,
#  'threw': 9032,
#  'hubbi': 4239,
#  'occas': 6090,
#  'prohibit': 6907,
#  'wonder': 10002,
#  'haha': 3940,
#  'men': 5465,
#  'bb': 714,
#  'novemb': 6021,
#  'http': 4235,
#  'thebooksofbabel': 8975,
#  'stormlight': 8579,
#  'octob': 6099,
#  'obes': 6068,
#  'run': 7603,
#  'hard': 3976,
#  'distract': 2461,
#  'chose': 1510,
#  'sanderson': 7691,
#  'minut': 5586,
#  'special': 8354,
#  'secret': 7838,
#  'pleasur': 6673,
#  'incent': 4394,
#  'reward': 7448,
#  'grow': 3871,
#  'kaladin': 4759,
#  'shallan': 7941,
#  'adventur': 107,
#  'hour': 4216,
#  'near': 5860,
#  'number': 6039,
#  'pound': 6784,
#  'today': 9119,
#  'path': 6443,
#  'ocean': 6095,
#  'hot': 4208,
#  'humid': 4250,
#  'tropic': 9283,
#  'afternoon': 137,
#  'cloudi': 1610,
#  'rain': 7115,
#  'threat': 9030,
#  'storm': 8577,
#  'air': 169,
#  'sea': 7817,
#  'shaft': 7934,
#  'cloud': 1609,
#  'spear': 8351,
#  'beneath': 785,
#  'energi': 2816,
#  'fli': 3273,
#  'imagin': 4349,
#  'bodi': 919,
#  'glanc': 3635,
#  'garmin': 3536,
#  'saw': 7733,
#  'km': 4852,
#  'realis': 7188,
#  'fast': 3106,
#  'moment': 5671,
#  'climax': 1594,
#  'sudden': 8679,
#  'hero': 4075,
#  'miracul': 5589,
#  'passag': 6428,
#  'sent': 7875,
#  'sky': 8135,
#  'assassin': 464,
#  'puf': 6974,
#  'lip': 5090,
#  'claim': 1563,
#  'caught': 1331,
#  'stood': 8570,
#  'stare': 8502,
#  'tumbl': 9311,
#  'steel': 8532,
#  'intent': 4521,
#  'word': 10012,
#  'cheek': 1440,
#  'cri': 1992,
#  'sad': 7636,
#  'wrong': 10065,
#  'angri': 294,
#  'bitter': 850,
#  'cynic': 2096,
#  'certain': 1379,
#  'grate': 3823,
#  'proper': 6919,
#  'rug': 7595,
#  'empti': 2789,
#  'coastlin': 1634,
#  'inspir': 4497,
#  'op': 6187,
#  'sometim': 8285,
#  'shit': 7999,
#  'happi': 3972,
#  'youv': 10194,
#  'constant': 1805,
#  'readjust': 7184,
#  'headphon': 4018,
#  'edit': 2717,
#  'congrat': 1786,
#  'weight': 9882,
#  'preliminari': 6823,
#  'stage': 8478,
#  'shape': 7948,
#  'idea': 4310,
#  'surpris': 8740,
#  'heavi': 4038,
#  'cosmer': 1896,
#  'mistborn': 5617,
#  'skyward': 8142,
#  'line': 5080,
#  'kalladin': 4762,
#  'slight': 8169,
#  'oathbring': 6064,
#  'battl': 706,
#  'whisper': 9931,
#  'shatter': 7956,
#  'forg': 3345,
#  'amaran': 245,
#  'identifi': 4314,
#  'situat': 8107,
#  'audio': 527,
#  'struggl': 8626,
#  'depress': 2271,
#  'hardest': 3980,
#  'contextu': 1824,
#  'accomplish': 49,
#  'congratul': 1787,
#  'proud': 6940,
#  'buddi': 1103,
#  'goosebump': 3702,
#  'brother': 1073,
#  'hey': 4082,
#  'atleast': 504,
#  'convey': 1845,
#  'power': 6791,
#  'journey': 4712,
#  'destin': 2301,
#  'entertain': 2840,
#  'latest': 4951,
#  'magic': 5267,
#  'exist': 2977,
#  'singl': 8096,
#  'overarch': 6286,
#  'togeth': 9125,
#  'lockdown': 5128,
#  'zoom': 10255,
#  'leav': 4987,
#  'long': 5142,
#  'walk': 9791,
#  'kept': 4796,
#  'sane': 7693,
#  'healthi': 4025,
#  'ugli': 9373,
#  'winter': 9971,
#  'perspect': 6538,
#  'rd': 7170,
#  'jealous': 4675,
#  'reader': 7181,
#  'quarantin': 7048,
#  'subscript': 8656,
#  'purchas': 6997,
#  'swing': 8779,
#  'close': 1603,
#  'sit': 8105,
#  'shelf': 7963,
#  'cascad': 1299,
#  'youll': 10183,
#  'clock': 1600,
#  'wander': 9803,
#  'endless': 2810,
#  'excercis': 2958,
#  'progress': 6906,
#  'driest': 2595,
#  'brightest': 1043,
#  'man': 5303,
#  'eastern': 2692,
#  'went': 9894,
#  'ran': 7131,
#  'answer': 314,
#  'fleet': 3268,
#  'spoken': 8415,
#  'song': 8291,
#  'lore': 5166,
#  'fastest': 3108,
#  'eer': 2724,
#  'known': 4866,
#  'surest': 8733,
#  'feet': 3145,
#  'roam': 7510,
#  'race': 7088,
#  'herald': 4071,
#  'chan': 1393,
#  'rach': 7090,
#  'defeat': 2211,
#  'quick': 7067,
#  'yell': 10144,
#  'goal': 3667,
#  'brash': 1012,
#  'bold': 927,
#  'undaunt': 9415,
#  'east': 2690,
#  'shore': 8017,
#  ...}

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features, df.subreddit, test_size=0.3, random_state=88)

# %%
X_train.shape
# Out:
# (3675, 10265)

# %%
X_test.shape
# Out:
# (1575, 10265)

# %%
classifier = MultinomialNB()
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
nr_correct = (y_test == classifier.predict(X_test)).sum()
nr_correct
# Out:
# 1246

# %%
nr_incorrect = y_test.size - nr_correct
fraction_wrong = nr_incorrect / (nr_correct + nr_incorrect)
print(f'The (testing) accuracy of the model is {1-fraction_wrong:.2%}')
# Out:
# The (testing) accuracy of the model is 79.11%

# %%
 classifier.score(X_test, y_test)
# Out:
# 0.7911111111111111

# %%
recall_score(y_test, classifier.predict(X_test), average=None)
# Out:
# array([0.82650602, 0.06666667, 0.90942029, 0.78333333, 0.08928571,
#        0.8125    , 0.13333333])

# %%
f1_score(y_test, classifier.predict(X_test), average=None)
# Out:
# array([0.83760684, 0.12      , 0.83112583, 0.76422764, 0.15873016,
#        0.82539683, 0.23529412])

# %%
example = ["Fellow sushi lover here! If y'all can't handle raw fish, we are done. I also love playing Call of Duty and Fortnite."]

# %%
doc_term_matrix = vectorizer.transform(example)

# %%
classifier.predict_proba(doc_term_matrix)
# Out:
# array([[8.65041326e-01, 4.14216645e-04, 9.43960809e-04, 1.05748275e-01,
#         1.04013433e-02, 1.67242799e-02, 7.26598295e-04]])

# %%
doc_term_matrix = vectorizer.transform(df.body)

# %%
classifier.predict_proba(doc_term_matrix)
# Out:
# array([[2.61652835e-51, 4.23686950e-73, 4.85969493e-36, ...,
#         6.92801110e-67, 1.83965366e-23, 2.68951771e-72],
#        [2.02225812e-37, 1.77745652e-46, 6.11007448e-31, ...,
#         2.20329331e-42, 3.74777454e-20, 3.81004948e-45],
#        [2.65671454e-05, 1.88695617e-07, 9.25255117e-01, ...,
#         6.14883206e-08, 4.25063419e-04, 7.63860125e-08],
#        ...,
#        [3.91230264e-08, 4.48555505e-16, 1.13810738e-07, ...,
#         4.54810864e-12, 9.99999830e-01, 2.45610610e-14],
#        [7.75584588e-06, 1.47845261e-11, 5.86151586e-04, ...,
#         4.63157889e-09, 9.96169913e-01, 9.72938029e-12],
#        [4.03028197e-03, 6.85017963e-05, 2.93263702e-01, ...,
#         8.42644309e-04, 6.62450683e-01, 6.91251401e-05]])

# %%
classifier.classes_
# Out:
# array(['Cooking', 'GYM', 'Games', 'books', 'cookingforbeginners',
#        'travel', 'videogames'], dtype='<U19')

# %%
df2 = pd.DataFrame(classifier.predict_proba(doc_term_matrix),
                   columns=classifier.classes_)

# %%
df2
# Out:
#            Cooking           GYM         Games         books  \
# 0     2.616528e-51  4.236869e-73  4.859695e-36  1.000000e+00
# 1     2.022258e-37  1.777457e-46  6.110074e-31  1.000000e+00
# 2     2.656715e-05  1.886956e-07  9.252551e-01  7.429293e-02
# 3     1.003784e-10  2.570686e-21  2.376721e-06  9.999976e-01
# 4     5.107115e-06  7.924552e-12  3.059542e-03  9.967195e-01
# ...            ...           ...           ...           ...
# 5245  1.139609e-01  2.962029e-03  4.141782e-01  2.115101e-01
# 5246  2.105934e-08  5.660870e-10  1.256772e-06  8.282606e-06
# 5247  3.912303e-08  4.485555e-16  1.138107e-07  1.728340e-08
# 5248  7.755846e-06  1.478453e-11  5.861516e-04  3.236175e-03
# 5249  4.030282e-03  6.850180e-05  2.932637e-01  3.927506e-02
#
#       cookingforbeginners        travel    videogames
# 0            6.928011e-67  1.839654e-23  2.689518e-72
# 1            2.203293e-42  3.747775e-20  3.810049e-45
# 2            6.148832e-08  4.250634e-04  7.638601e-08
# 3            8.058590e-18  5.337643e-09  9.400412e-22
# 4            7.353764e-10  2.158704e-04  5.011602e-11
# ...                   ...           ...           ...
# 5245         4.258181e-03  2.531163e-01  1.429582e-05
# 5246         7.243394e-11  9.999904e-01  9.140044e-13
# 5247         4.548109e-12  9.999998e-01  2.456106e-14
# 5248         4.631579e-09  9.961699e-01  9.729380e-12
# 5249         8.426443e-04  6.624507e-01  6.912514e-05
#
# [5250 rows x 7 columns]

# %%
df2.to_csv('new_dataframe.csv')
